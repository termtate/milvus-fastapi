# %%
import httpx  # 或者可以使用requests
from model import Patient
from pydantic import parse_raw_as
import asyncio
from pprint import pprint

url = "http://127.0.0.1:8000/api/v1/patients"

# %%
def get(url: str, params: dict | None = None) -> list[Patient]:
    res = httpx.get(url, params=params, follow_redirects=True) # 需要加follow_redirects允许重定向
    print(res.content)
    response = parse_raw_as(list[Patient], res.content)  # 解析响应的json为Patient类
    return response

# 或者可以异步调用
async def async_call(url: str, params: dict | None = None):
    async with httpx.AsyncClient() as client:
        get = await client.get(url, params=params)
        response = parse_raw_as(list[Patient], get.content)
        pprint(response)

# %%
pprint(get(f"{url}/123002"))  # 查询id为123002的病人
# Out:
# [Patient(id=123002,
#          id_card_number='\\N',
#          name='李十一',
#          hospitalize_num='第(3)次入院记录',
#          case_number='7040830',
#          sex='女',
#          age='15岁4月',
#          phone_number='11448617085',
#          seizure_evolution='表现为脱衣，起“鸡皮疙瘩”，词不达意,髋部扭动，语言不流利，呼之不应,点头痉挛发作，受到刺激，舔舌，发作后想睡觉，面色青紫,心动过速，睡眠中突然醒来出现惊厥,胡言论语,心跳停止,精神紧张出现惊厥,瘫倒到地上,心动过缓，发作后易激惹,疲惫出现惊厥，精神紧张出现抽搐，头眼向左偏转，面色潮红，发作后面部无力,语言障碍，；')]

# %%
await async_call(f"{url}/123002") # 异步调用
# Out:
# [Patient(id=123002, id_card_number='\\N', name='李十一', hospitalize_num='第(3)次入院记录', case_number='7040830', sex='女', age='15岁4月', phone_number='11448617085', seizure_evolution='表现为脱衣，起“鸡皮疙瘩”，词不达意,髋部扭动，语言不流利，呼之不应,点头痉挛发作，受到刺激，舔舌，发作后想睡觉，面色青紫,心动过速，睡眠中突然醒来出现惊厥,胡言论语,心跳停止,精神紧张出现惊厥,瘫倒到地上,心动过缓，发作后易激惹,疲惫出现惊厥，精神紧张出现抽搐，头眼向左偏转，面色潮红，发作后面部无力,语言障碍，；')]

# %%
pprint(get(url, params={"sex": "男"}))
# Out:
# b'[{"id":123004,"id_card_number":"\\\\N","name":"\xe5\x90\xb4\xe5\x9b\x9b\xe5\x85\xad","hospitalize_num":"\xe7\xac\xac(2)\xe6\xac\xa1\xe5\x85\xa5\xe9\x99\xa2\xe8\xae\xb0\xe5\xbd\x95","case_number":"682741","sex":"\xe7\x94\xb7","age":"2\xe5\xb2\x8110\xe6\x9c\x88","phone_number":"85890969518","seizure_evolution":"\xe8\xa1\xa8\xe7\x8e\xb0\xe4\xb8\xba\xe9\x97\xbb\xe5\x88\xb0\xe7\xb3\x8a\xe5\x91\xb3,,\xe6\xb8\x85\xe9\x86\x92\xe7\x8a\xb6\xe6\x80\x81\xe6\x97\xb6\xe5\x87\xba\xe7\x8e\xb0\xe6\x8a\xbd\xe6\x90\x90\xef\xbc\x8c\xe7\x96\xbc\xe7\x97\x9b\xef\xbc\x8c\xe5\x8f\x8c\xe4\xb8\x8b\xe8\x82\xa2\xe8\xb9\xac\xe8\xb8\x8f,
\xb4\xe9\x83\xa8\xe9\x9a\xbe\xe4\xbb\xa5\xe8\xa7\xa3\xe9\x87\x8a\xe7\x9a\x84\xe6\x84\x9f\xe8\xa7\x89,\xe8\x83\x83\xe6\xb0\x94\xe4\xb8\x8a\xe5\x8d\x87\xe6\x84\x9f,,\xe5\xa4\xb1\xe8\xaf\xad,\xe7\x96\xb2\xe5\x8a\xb3\xe5\x87\xba\xe7\x8e\xb0\xe6\x83\x8a\xe5\x8e\xa5\xef\xbc\x8c\xe5\x91\x95\xe5\x90\x90,\xe7\x97\xb4\xe7\xac\x91,\xe9\xba\xbb\xe6\x9c\xa8\xef\xbc\x8c\xe5\x90\xac\xe5\x88\xb0\xe4\xb9\x90\xe6\x9b\xb2,\xe5\x8f\x91\xe4\xbd\x9c\xe5\x90\x8e\xe4\xb9\x8f\xe5\x8a\x9b,\xe7\x86\xac\xe5\xa4\x9c\xe5\x87\xba\xe7\x8e\xb0\xe6\x83\x8a\xe5\x8e\xa5\xef\xbc\x8c\xe7\x81\xb5\xe9\xad\x82\xe5\x87\xba\xe7\xaa\x8d,\xe4\xbc\xb4\xe5\x8f\x91\xe7\x83\xad\xef\xbc\x8c\xe5\x8f\x91\xe4\xbd\x9c\xe5\x90\x8e\xe8\x82\x8c\xe8\x82\x89\xe9\x85\xb8\xe7\x97\x9b,\xe9\x9d\xa2\xe8\x89\xb2\xe5\x8f\x91 ...
# [Patient(id=123004,
#          id_card_number='\\N',
#          name='吴四六',
#          hospitalize_num='第(2)次入院记录',
#          case_number='682741',
#          sex='男',
#          age='2岁10月',
#          phone_number='85890969518',
#          seizure_evolution='表现为闻到糊味,出汗，疲惫出现惊厥，跑步出现惊厥，睡眠中突然醒来出现抽搐,清醒状态时出现抽搐，疼痛，双下肢蹬踏,腹泻后出现惊厥，闻到烧焦的气味,意识丧失，面色发紫,不睡觉出现惊厥，面色发绀，饮酒后出现惊厥,外界的声音变近，大便失禁,快乐,小便失禁,发作后嗜睡，受到刺激,疲惫出现抽搐,上肢挥舞,肢体阵挛性抽动,清醒状态时出现惊厥，。'),
#  Patient(id=123005,
#          id_card_number='\\N',
#          name='曹九一',
#          hospitalize_num='第(4)次入院记录',
#          case_number='4945601',
#          sex='男',
#          age='1岁4月',
#          phone_number='34861707803',
#          seizure_evolution='表现为疲劳出现抽搐,尿失禁,“就像在镜头前”看到自己，上肢挥舞，大便失禁,头部难以解释的感觉,胃气上升感,走路出现抽搐，四肢外展，口唇青紫，疲惫出现抽搐，词不达意,失语,疲劳出现惊厥，呕吐,痴笑,麻木，听到乐曲,发作后乏力,熬夜出现惊厥，灵魂出窍,伴发热，发作后肌肉酸痛,面色发绀,口中发声，。'),
#  Patient(id=123009,
#          id_card_number='\\N',
#          name='蒋八二',
#          hospitalize_num='第(0)次入院记录',
#          case_number='6272622',
#          sex='男',
#          age='11岁0月',
#          phone_number='25871064818',
#          seizure_evolution='表现为搓手,反应迟缓,语言障碍，舔舌,睡眠中突然醒来出现惊厥，点头成串发作,流泪，对外界刺激无反应，四肢屈曲，流涎,夜晚睡眠中出现抽搐，上肢挥舞，发作后失语，伴发热，反应迟钝,刚刚醒来出现抽搐,痴笑,发作后易激惹，高兴，白天睡眠中出现抽搐，熬夜出现惊厥，起“鸡皮疙瘩”,大笑，尿失禁，眼球震颤,；'),
#  Patient(id=123010,
#          id_card_number='\\N',
#          name='蒋六七',
#          hospitalize_num='第(6)次入院记录',
#          case_number='5659629',
#          sex='男',
#          age='2岁1月',
#          phone_number='61880489550',
#          seizure_evolution='表现为阴茎勃起，舔舌，出汗，咀嚼，饮酒后出现抽搐,麻刺感，对外界刺激无反应,眼球偏转，高兴，闻到糊味，听到铃声，咂嘴,胃气上升感,点头痉挛发作，梦样状态，上肢划船样运动,疲惫出现抽搐，腹泻后出现抽搐,面色发绀，听到噪音，精神紧张出现抽搐，面色发紫，听到说话声，发作后下肢无力，四肢外展，；'),
#  Patient(id=123012,
#          id_card_number='\\N',
#          name='李六四',
#          hospitalize_num='第(5)次入院记录',
#          case_number='1466290',
#          sex='男',
#          age='0岁3月',
#          phone_number='7202291951',
#          seizure_evolution='表现为发作后肌肉酸痛，便失禁，听到蜂鸣声,反应迟钝,点头痉挛发作,恐惧，四肢外展,饮酒后出现惊厥，梦样状态，四肢屈曲，语言障碍,疲劳出现惊厥,灵魂出窍，发热出现抽搐,流泪,闻到烧胶皮味，精神紧张出现惊厥，胡言论语，心跳停止,发作后头痛,肌肉快速收缩，心动过缓，外界的声音变远，疲惫出现抽搐，睡眠中突然醒来出现抽搐，；'),
#  Patient(id=123015,
#          id_card_number='\\N',
#          name='蒋十九',
#          hospitalize_num='入院记录(4)',
#          case_number='372781',
#          sex='男',
#          age='12岁10月',
#          phone_number='58567521842',
#          seizure_evolution='表现为不伴发热，发作后言语障碍,不睡觉出现惊厥,阴茎勃起,灼烧感,外界的声音变近,饮酒后出现惊厥，解扣子,无反应，夜晚睡眠中出现惊厥,心跳停止,心动过缓，肌肉快速收缩，四肢屈曲，听到说话声，发作后立即恢复正常,心动过速，发作后臂部无力，发作后失语，疼痛，生疏感,白天睡眠中出现抽搐,脱衣，心悸,跑步出现惊厥,。'),
#  Patient(id=123016,
#          id_card_number='\\N',
#          name='蒋九六',
#          hospitalize_num='第(0)次入院记录',
#          case_number='3296086',
#          sex='男',
#          age='0岁7月',
#          phone_number='3639412802',
#          seizure_evolution='表现为走路出现惊厥,发作后头痛，头眼向左偏转,小便失禁，疲惫出现抽搐，夜晚睡眠中出现惊厥，口中发声,摸索衣服,阴茎勃起，发热出现惊厥,吞咽,尿失禁,梦样状态，发作后肌肉酸痛,看到小时候场景,高兴，白天睡眠中出现惊厥，不睡觉出现惊厥,髋部扭动,动作停止，焦虑出现抽搐,无法集中注意力,发作后嗜睡,白天睡眠中出现抽搐，事后不能回忆,；'),
#  Patient(id=123019,
#          id_card_number='\\N',
#          name='孙十七',
#          hospitalize_num='第(1)次入院记录',
#          case_number='7755881',
#          sex='男',
#          age='2岁2月',
#          phone_number='26871033190',
#          seizure_evolution='表现为头眼向右偏转，精神紧张出现抽搐,发作后想睡觉，反应迟缓，刚刚醒来出现惊厥,手搓丸，不睡觉出现惊厥,害怕，便失禁,发作后乏力，心悸，击剑样”姿势，眨眼，肌肉快速收缩,痴笑，作操出现抽搐，听到乐曲,外界的声音变近，肢体阵挛性抽动，清醒状态时出现抽搐，焦虑出现抽搐,大便失禁,发作后嗜睡,发作后易激惹，愤怒，。'),
#  Patient(id=123020,
#          id_card_number='\\N',
#          name='吴十四',
#          hospitalize_num='入院记录(3)',
#          case_number='9093051',
#          sex='男',
#          age='12岁10月',
#          phone_number='26357799000',
#          seizure_evolution='表现为灵魂出窍,不睡觉出现抽搐,起“鸡皮疙瘩”,听到铃声，寒战，肌肉快速抽动，疼痛，疲劳出现惊厥，杰克逊发作,胡言论语，点头,头眼向左偏转,“4”字征,精神紧张出现惊厥，发作后言语障碍，流口水，熟悉感,四肢外展,麻刺感,睡眠中突然醒来出现惊厥,面色泛红，肌肉快速收缩，焦虑出现抽搐,不睡觉出现惊厥,阴茎勃起，；'),
#  Patient(id=123021,
#          id_card_number='\\N',
#          name='潘九一',
#          hospitalize_num='入院记录(3)',
#          case_number='8656',
#          sex='男',
#          age='12岁10月',
#          phone_number='66773381174',
#          seizure_evolution='表现为清醒状态下出现抽搐,闻到烧焦的气味，发热出现抽搐，听到蜂鸣声,四肢外展,发作后嗜睡,熟悉感，口唇青紫，头眼向右偏转，疲劳出现抽搐，睡眠中突然醒来出现惊厥,胃气上升感，外界的声音变近，麻木,腹泻后出现抽搐，跑步出现抽搐,疲惫出现抽搐,情绪激动,肌肉快速抽动,心动过缓,听到噪音，哭泣,闻到烧羽毛味,饮酒后出现抽搐，髋部扭动,。'),
#  Patient(id=123030,
#          id_card_number='\\N',
#          name='曹十一',
#          hospitalize_num='第(2)次入院记录',
#          case_number='5359327',
#          sex='男',
#          age='15岁1月',
#          phone_number='32122800729',
#          seizure_evolution='表现为击剑样”姿势，恐惧,瘫倒到地上，闻到烧焦的气味，灵魂出窍，反应迟缓,上肢投掷样运动,咀嚼,发作后面部无力,焦虑出现惊厥,高兴,痴笑，外界的声音变远,外界的声音变大，饮酒后出现惊厥，面色青紫，发作后臂部无力，注意力不集中,发作后下肢无力,口唇青紫，解扣子，奔跑,眼球偏转,尿失禁，外界的声音变近，。')]

# %%
pprint(get(f"{url}/ann_search", params={  # 向量相似查询
    "query": "闻到糊味",
    # "limit": 10  # limit参数可选，默认10
}))
# Out:
\x88\xb0\xe7\xb3\x8a\xe5\x91\xb3","score":3.644911289215088},{"id":123029,"id_card_number":"\\\\N","name":"\xe8\xb5\xb5\xe5\x8d\x81\xe5\x85\xad","hospitalize_num":"\xe5\x85\xa5\xe9\x99\xa2\xe8\xae\xb0\xe5\xbd\x95(5)","case_number":"9066570","sex":"\xe5\xa5\xb3","age":"13\xe5\xb2\x819\xe6\x9c\x88","phone_number":"95445338782","seizure_evolution":",\xe6\x91\xb8\xe7\xb4\xa2\xe8\xa1\xa3\xe6\x9c\x8d,\xe4\xb8\x8d\xe7\x9d\xa1\xe8\xa7\x89\xe5\x87\xba\xe7\x8e\xb0\xe6\x83\x8a\xe5\x8e\xa5\xef\xbc\x8c\xe7\x82\xb9\xe5\xa4\xb4\xef\xbc\x8c\xe5\x91\x95\xe5\x90\x90,\xe5\xa4\x9c\xe6\x99\x9a\xe7\x9d\xa1\xe7\x9c\xa0\xe4\xb8\xad\xe5\x87\xba\xe7\x8e\xb0\xe6\x8a\xbd\xe6\x90\x90\xef\xbc\x8c\xe7\x81\xb5\xe9\xad\x82\xe5\x87\xba\xe7\xaa\x8d\xef\xbc\x8c\xe7\x98\xab\xe5\x80\x92\xe5\x88\xb0\xe5\x9c\xb0\xe4\xb8\x8a,\xe8\xaf\x8d\xe4\xb8\x8d\xe8\xbe\xbe\xe6\x84\x8f,\xe8\x82\xa2\xe4\xbd\x93\xe9\x98\xb5\xe6\x8c\x9b\xe6\x80\xa7\xe6\x8a\xbd\xe5\x8a\xa8,\xe9\xab\x8b\xe9\x83\xa8\xe7\xbf\xbb\xe8\xbd\xac,,\xe5\xa4\x96\xe7\x95\x8c\xe7\x9a\x84\xe5\xa3\xb0\xe9\x9f\xb3\xe5\x8f\x98\xe8\xbf\x9c,\xe5\x8f\x91\xe4\xbd\x9c\xe5\x90\x8e\xe7\xab\x8b\xe5\x8d\xb3\xe6\x81\xa2\xe5\xa4\x8d\xe6\xad\xa3\xe5\xb8\xb8,\xe7\x94\x9f\xe7\x96\x8f\ ...
# [Patient(id=123004,
#          id_card_number='\\N',
#          name='吴四六',
#          hospitalize_num='第(2)次入院记录',
#          case_number='682741',
#          sex='男',
#          age='2岁10月',
#          phone_number='85890969518',
#          seizure_evolution='表现为闻到糊味,出汗，疲惫出现惊厥，跑步出现惊厥，睡眠中突然醒来出现抽搐,清醒状态时出现抽搐，疼痛，双下肢蹬踏,腹泻后出现惊厥，闻到烧焦的气味,意识丧失，面色发紫,不睡觉出现惊厥，面色发绀，饮酒后出现惊厥,外界的声音变近，大便失禁,快乐,小便失禁,发作后嗜睡，受到刺激,疲惫出现抽搐,上肢挥舞,肢体阵挛性抽动,清醒状态时出现惊厥，。'),
#  Patient(id=123029,
#          id_card_number='\\N',
#          name='赵十六',
#          hospitalize_num='入院记录(5)',
#          case_number='9066570',
#          sex='女',
#          age='13岁9月',
#          phone_number='95445338782',
#          seizure_evolution='表现为刚刚醒来出现惊厥，发热出现抽搐，闻到烧羽毛味,摸索衣服,不睡觉出现惊厥，点头，呕吐,夜晚睡眠中出现抽搐，灵魂出窍，瘫倒到地上,词不达意,肢体阵挛性抽动,髋部翻转,出汗，焦虑出现惊厥，发作后臂部无力，对外界刺激无反应,外界的声音变远,发作后立即恢复正常,生疏感,发作后易激惹，受到刺激，面色苍白,愤怒,刚刚醒来出现抽搐，。'),
#  Patient(id=123026,
#          id_card_number='\\N',
#          name='张五九',
#          hospitalize_num='入院记录(3)',
#          case_number='9721131',
#          sex='女',
#          age='11岁2月',
#          phone_number='86459539294',
#          seizure_evolution='表现为发作后易激惹,害怕，髋部扭动，熟悉感,发作后有攻击性，愣神,刚刚醒来出现抽搐,瘫倒到地上,上肢划船样运动,高兴,跑步出现抽搐，看到小时候场景,发作后下肢无力，上肢投掷样运动，精神紧张出现抽搐，面色发绀，发作后嗜睡，腹泻后出现惊厥，寒战，走路出现抽搐，发作后面部无力，闻到糊味,口唇发紫，心跳快，疲惫出现抽搐，。'),
#  Patient(id=123021,
#          id_card_number='\\N',
#          name='潘九一',
#          hospitalize_num='入院记录(3)',
#          case_number='8656',
#          sex='男',
#          age='12岁10月',
#          phone_number='66773381174',
#          seizure_evolution='表现为清醒状态下出现抽搐,闻到烧焦的气味，发热出现抽搐，听到蜂鸣声,四肢外展,发作后嗜睡,熟悉感，口唇青紫，头眼向右偏转，疲劳出现抽搐，睡眠中突然醒来出现惊厥,胃气上升感，外界的声音变近，麻木,腹泻后出现抽搐，跑步出现抽搐,疲惫出现抽搐,情绪激动,肌肉快速抽动,心动过缓,听到噪音，哭泣,闻到烧羽毛味,饮酒后出现抽搐，髋部扭动,。'),
#  Patient(id=123011,
#          id_card_number='\\N',
#          name='吴四七',
#          hospitalize_num='入院记录(9)',
#          case_number='9831834',
#          sex='女',
#          age='3岁6月',
#          phone_number='13868179064',
#          seizure_evolution='表现为外界的声音变大,灵魂出窍,熬夜出现抽搐,夜晚睡眠中出现抽搐,腹泻后出现惊厥，清醒状态下出现惊厥,饮酒后出现惊厥,头眼向左偏转，不睡觉出现抽搐,白天睡眠中出现惊厥，伴发热,心跳停止,髋部扭动,慢慢倒地,腹泻后出现抽搐，发作后乏力，蹦跳,便失禁，闻到烧焦的气味,出汗，听到乐曲，击剑样”姿势，生疏感，杰克逊发作，上肢划船样运动，。'),
#  Patient(id=123024,
#          id_card_number='\\N',
#          name='周一八',
#          hospitalize_num='入院记录(3)',
#          case_number='7384541',
#          sex='女',
#          age='7岁8月',
#          phone_number='86762634318',
#          seizure_evolution='表现为闻到烧胶皮味，外界的声音变近,语言不流利，心跳快,睡眠中突然醒来出现惊厥，发作后臂部无力,精神紧张出现惊厥,发作后面部无力，腹泻后出现抽搐，精神紧张出现抽搐，失语,头部难以解释的感觉,蹦跳，发作后嗜睡，听到蜂鸣声，动作停止,麻刺感,咀嚼，疲惫出现抽搐,外界的声音变大，词不达意，清醒状态下出现抽搐，点头,发作后立即恢复正常,胃气上升感,。'),
#  Patient(id=123008,
#          id_card_number='\\N',
#          name='潘二八',
#          hospitalize_num='第(5)次入院记录',
#          case_number='2614738',
#          sex='女',
#          age='18岁4月',
#          phone_number='72851289917',
#          seizure_evolution='表现为眼球偏转，面色发绀,面色泛红,刚刚醒来出现惊厥，大便失禁，发作后嗜睡，饮酒后出现抽搐,反应迟钝，疲劳出现惊厥，发作后下肢无力,灼烧感,发作后乏力，口唇发绀,小便失禁，双下肢蹬踏，发作后失语，出汗,失语,外界的声音变大,闻到糊味，四肢屈曲，流口水,四肢外展,作操出现抽搐,心悸,。'),
#  Patient(id=123030,
#          id_card_number='\\N',
#          name='曹十一',
#          hospitalize_num='第(2)次入院记录',
#          case_number='5359327',
#          sex='男',
#          age='15岁1月',
#          phone_number='32122800729',
#          seizure_evolution='表现为击剑样”姿势，恐惧,瘫倒到地上，闻到烧焦的气味，灵魂出窍，反应迟缓,上肢投掷样运动,咀嚼,发作后面部无力,焦虑出现惊厥,高兴,痴笑，外界的声音变远,外界的声音变大，饮酒后出现惊厥，面色青紫，发作后臂部无力，注意力不集中,发作后下肢无力,口唇青紫，解扣子，奔跑,眼球偏转,尿失禁，外界的声音变近，。'),
#  Patient(id=123006,
#          id_card_number='\\N',
#          name='蒋七一',
#          hospitalize_num='入院记录(5)',
#          case_number='6041732',
#          sex='女',
#          age='4岁1月',
#          phone_number='63229481568',
#          seizure_evolution='表现为饮酒后出现抽搐，眨眼，白天睡眠中出现抽搐，灵魂出窍，睡眠中突然醒来出现抽搐,击剑样”姿势,清醒状态下出现惊厥,心跳停止,头部难以解释的感觉,出汗，醒后不久出现惊厥,腹泻后出现惊厥,跑步出现抽搐，感觉身体离开自己，上肢投掷样运动，注意力不集中，走路出现惊厥，口唇发绀,疲惫出现惊厥,发作后头痛,愣神，吞咽，流泪,饮酒后出现惊厥,刚刚醒来出现抽搐,。'),
#  Patient(id=123025,
#          id_card_number='\\N',
#          name='潘八三',
#          hospitalize_num='入院记录(1)',
#          case_number='6506700',
#          sex='女',
#          age='10岁0月',
#          phone_number='32563883245',
#          seizure_evolution='表现为发作后嗜睡,白天睡眠中出现抽搐,“就像在镜头前”看到自己,饮酒后出现抽搐,面色苍白,胃气上升感，失语，发作后易激惹，白天睡眠中出现惊厥,作操出现惊厥，发作后下肢无力，梦样状态，愤怒，出汗，恐惧,麻刺感,发热出现惊厥，疲劳出现抽搐,摸索衣服,发作后有攻击性,眼球震颤,作操出现抽搐,咀嚼，寒战，面色发绀,。')]

# %%
pprint(httpx.post(url, json=[
  {
    "id": 0,
    "id_card_number": "string",
    "name": "test",
    "hospitalize_num": "string",
    "case_number": "string",
    "sex": "男",
    "age": "string",
    "phone_number": "string",
    "seizure_evolution": "string"
  }
], follow_redirects=True))
# Out:
# <Response [200 OK]>

# %%
pprint(httpx.delete(f"{url}/0"))
# Out:
# <Response [200 OK]>
